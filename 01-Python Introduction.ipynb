# %% [markdown]
# ###### <span style ='color:green'>vineethreddy@techie👨‍💻</span>

# %% [markdown]
# # Python Introduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Topics
# * What is Programming?
# * What is Coding?
# * What is Python
# * Python Used for?
# * What can Python do?
# * Why Python?
# * Python Library
# * Python Modules
# * Python Webframework
# * Syntax of Python
# * Execute Python Syntax
# * Python Syntax compared to other programming languages
# * Python Installation
# * Install The Jupyter Notebook for Writing Code (Mainly for Data Science Purposes)

# %% [markdown]
# ### What is Programming?

# %% [markdown]
# > Programming is the process of creating a set of instructions that tell a computer how to perform a task. Programming can be done using a variety of computer programming languages, such as C, java, JavaScript, Python, C++,etc,,.

# %% [markdown]
# ### What is coding?

# %% [markdown]
# > Coding, sometimes called computer programming, is how we communicate with computers. Code tells a computer what actions to take, and writing code is like creating a set of instructions. By learning to write code, you can tell computers what to do or how to behave in a much faster way.

# %% [markdown]
# ### What is Python?
# >Python is a popular programming language , high level language and object oriented programming language . It was created by Guido van Rossum, and released in 1991.

# %% [markdown]
# ### Python Used for?
# * web development (server-side),
# * software development,
# * system scripting,
# * Data Science Applications,
# * Artificial Inteligence.

# %% [markdown]
# ### What can Python do?
# * Python can be used on a server to create web applications.
# * Python can be used alongside software to create workflows.
# * Python can connect to database systems. It can also read and modify files.
# * Python can be used to handle big data and perform complex mathematics.
# * Python can be used for rapid prototyping, or for production-ready software development.

# %% [markdown]
# ### Why Python?
# * Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
# * Python has a simple syntax similar to the English language.
# * Python has syntax that allows developers to write programs with fewer lines than some other programming languages.
# * Python runs on an interpreter system, meaning that code can be executed as soon as it is written.
# * This means that prototyping can be very quick.
# * Python can be treated in a procedural way, or a functional way or an object-oriented way.

# %% [markdown]
# ### What is Python Library?
# > A Python library is a collection of related modules. It contains bundles of code that can be used repeatedly in different programs. It makes Python Programming simpler and convenient for the programmer. As we don’t need to write the same code again and again for different programs. Python libraries play a very vital role in fields of Machine Learning, Data Science, Data Visualization, etc.

# %% [markdown]
# ### What is Module?
# > A Python module is a file containing Python definitions and statements. A module can define functions, classes, and variables. A module can also include runnable code. Grouping related code into a module makes the code easier to understand and use. It also makes the code logically organized.

# %% [markdown]
# ### What is web framework in python?
# > Python Web framework is a collection of packages or modules that allow developers to write Web applications or services. With it, developers don't need to handle low-level details like protocols, sockets or process/thread management.

# %% [markdown]
# ### Syntax of Python
# > Python syntax can be executed by writing directly in the Command Line:
# > #### >>> print("Hello, World!")

# %% [markdown]
# ### Execute Python Syntax
# * Or by creating a python file on the server, using the .py file extension,
# and running it in the Command Line:
# * C:\Users\folder name>python myfile.py

# %% [markdown]
# ### Basic Syntax

# %%
#Basic Programm
print("Hello This Is Vineeth Reddy")
print("I am From Hyderabad")

## Print is the keyword to use printing the statement to screening the output
# Out:
# Hello This Is Vineeth Reddy
# I am From Hyderabad

# %% [markdown]
# ### Python Syntax compared to other programming languages
# * Python was designed for readability, and has some similarities to the English language with influence from mathematics.
# * Python uses new lines to complete a command, as opposed to other programming languages which often use semicolons or parentheses.
# * Python relies on indentation, using whitespace, to define scope; such as the scope of loops, functions and classes.
# * Other programming languages often use curly-brackets for this purpose."""

# %% [markdown]
# ### Python Installation

# %% [markdown]
# ###### 1.Open a browser to the Python website and download the Windows installer.
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 2. Double click on the downloaded file and install Python for all users, and ensure that Python is added to your path. Click on Install now to begin. Adding Python to the path will enable us to use the Python interpreter from any part of the filesystem.
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 3. After the installation is complete, click Disable path length limit and then Close. Disabling the path length limit means we can use more than 260 characters in a file path.
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 4. Click Close to end the installation.
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Running Python in Widows
# ###### 1. Open a Command Prompt and type “python” then press Enter.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installing Jupyter Notebook using Anaconda

# %% [markdown]
# ###### 1.Please go to the Anaconda.com/downloads site
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 2. Select the respective platform: Windows/Mac/Linux
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Download the 64-bit .exe installer and install it
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Before installing pip packages, it's important to check the version of pip installed on your system. If your pip version is outdated, you'll need to update it to the latest version.
#
# * To update pip, use the following command:
#
#     * python -m pip install --upgrade pip

# %% [markdown]
# ##### Now Launch the Jupyter:
# * Use the command to launch Jupyter using command-line: jupyter notebook
#
# ##### Note: If you encounter any errors when running this command, you can resolve them by adding your Anaconda path to the system environment variables.

# %% [markdown]
# #### <font color='green'> Created by [Vineeth Reddy](https://linktr.ee/vineethreddy1997)</font>
